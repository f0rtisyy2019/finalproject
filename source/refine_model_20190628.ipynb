# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('new_model.csv')
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#    Price  Year  Mileage          City State                Vin   Make  \
# 0  15749  2015    27592      Highland    IN  KL4CJASB5FB245057  Buick
# 1  17020  2016    16877  Grand Island    NY  KL4CJASB7GB536760  Buick
# 2  15950  2015    27885   West Covina    CA  KL4CJASB3FB241802  Buick
# 3  17700  2015    13807  Jacksonville    NC  KL4CJBSB8FB068543  Buick
# 4  17491  2016    11123       Memphis    TN  KL4CJASBXGB720588  Buick
#
#                Model  Age
# 0          EncoreFWD    3
# 1          EncoreFWD    2
# 2          EncoreFWD    3
# 3  EncoreConvenience    3
# 4          EncoreFWD    2

# %%
df['State'].value_counts()
# Out:
#  TX    126523
#  CA    103939
#  FL     96301
#  GA     49872
#  IL     48767
#  NC     47604
#  VA     43251
#  PA     36780
#  NY     36019
#  NJ     34448
#  OH     30680
#  AZ     29410
#  WA     28672
#  CO     28191
#  TN     24954
#  MA     24620
#  MD     23362
#  MO     21474
#  IN     20862
#  KY     18190
#  AL     16835
#  WI     14973
#  MN     14302
#  MI     13750
#  CT     13635
#  OK     13535
#  UT     13463
#  OR     12908
#  SC     12803
#  LA     10881
#  KS     10079
#  NV      9462
#  AR      8818
#  MS      7835
#  NH      7662
#  NM      6479
#  NE      6285
#  IA      6180
#  ID      4254
#  DE      3528
#  HI      3113
#  ME      2471
#  RI      2444
#  MT      2368
#  AK      2055
#  WV      1913
#  ND      1649
#  VT      1429
#  SD      1421
#  Fl      1029
#  WY       875
#  Va       371
#  Md       226
#  Ga       192
#  ga       170
#  Az        80
#  Oh        80
#  Ca        42
#  DC        19
# Name: State, dtype: int64

# %%
df['Mileage'].describe()
# Out:
# count    1.103533e+06
# mean     4.781715e+04
# std      3.300405e+04
# min      5.000000e+00
# 25%      2.356700e+04
# 50%      3.903500e+04
# 75%      6.634100e+04
# max      1.499990e+05
# Name: Mileage, dtype: float64

# %%
df.count()
# Out:
# Price      1103533
# Year       1103533
# Mileage    1103533
# City       1103533
# State      1103533
# Vin        1103533
# Make       1103533
# Model      1103533
# Age        1103533
# dtype: int64

# %%
print(df.shape)
states = ['DC', 'AZ', 'HI', 'ga', 'WY', 'MT', 'SD']

index = df[~df['Year'].isin(['Year'])]
index
# Out:
# (1103533, 9)
#          Price  Year  Mileage               City State                Vin  \
# 0        15749  2015    27592           Highland    IN  KL4CJASB5FB245057
# 1        17020  2016    16877       Grand Island    NY  KL4CJASB7GB536760
# 2        15950  2015    27885        West Covina    CA  KL4CJASB3FB241802
# 3        17700  2015    13807       Jacksonville    NC  KL4CJBSB8FB068543
# 4        17491  2016    11123            Memphis    TN  KL4CJASBXGB720588
# 5        16699  2015    21323         Clearwater    FL  KL4CJASB2FB127080
# 6        15239  2015    20681             Dallas    TX  KL4CJBSB2FB179802
# 7        16814  2015    11541        Gainesville    FL  KL4CJASB0FB248111
# 8        17222  2015    10652      Oklahoma City    OK  KL4CJBSB9FB270758
# 9        16476  2015    21962           Flemming    GA  KL4CJBSB4FB231253
# 10       16450  2014    12760           Columbus    OH  KL4CJASBXEB752616
# ...

# %%
df['State'].head(1).value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-37ca7ac47774> in <module>
# ----> 1 df['State'].head(1).value
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value'
